# %%
# import the module 
import tweepy 

# assign the values accordingly 
consumer_key = "f9sBer1OHr4n87Tb2CRf9tOnR" 
consumer_secret = "68TlatsxXChb6bGygLCBy3NxrQtVJSt1oz4Jqk5kHdyUT62ZN9" 
access_token = "1515918522584825856-YqXuMsgEjMSFGlUN7y9DvKvDb34Y4n" 
access_token_secret = "LRbesAkxDYt7Ite47cZsWKJPmiMF9Zan1fVcgOs4Zx0UD" 

# authorization of consumer key and consumer secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 

# set access to user's access key and access secret 
auth.set_access_token(access_token, access_token_secret) 

# calling the api 
api = tweepy.API(auth) 

# the ID of the user 
#id = "@sushilkumar_sr"
# fetching the user 
tweets_list = tweepy.Cursor(api.search_tweets, q="from: covid19", lang='en').items(1)


# fetching the create_at attribute 
for i in tweets_list:
    print(i)
# Out:
# Status(_api=<tweepy.api.API object at 0x0000021108FC3DC0>, _json={'created_at': 'Fri May 06 05:04:30 +0000 2022', 'id': 1522442158267334657, 'id_str': '1522442158267334657', 'text': 'RT @BefittingFacts: .@WHO had said that Chinese authorities have not found evidence of human-to-human transmission of Covid19 and WHO prais…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BefittingFacts', 'name': 'Facts', 'id': 1289235667516456962, 'id_str': '1289235667516456962', 'indices': [3, 18]}, {'screen_name': 'WHO', 'name': 'World Health Organization (WHO)', 'id': 14499829, 'id_str': '14499829', 'indices': [21, 25]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1114797696, 'id_str': '1114797696', 'name': 'Nationalist_16 🇮🇳', 'screen_name': 'Nationalist_16', 'location': 'pondicherry', 'description': 'Retweets not my endorsement', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 252, 'friends_count': 339, 'listed_count': 5, 'created_at': 'Wed Jan 23 16:57:33 +0000 2013', 'favourites_count': 208841, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 102218, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/825419482378051584/WmlDlOYl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825419482378051584/WmlDlOYl_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1114797696/1542990598', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri May 06 04:17:49 +0000 2022', 'id': 1522430408025026560, 'id_str': '1522430408025026560', 'text': '.@WHO had said that Chinese authorities have not found evidence of human-to-human transmission of Covid19 and WHO p… https://t.co/JqUe1dAgHG', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'WHO', 'name': 'World Health Organization (WHO)', 'id': 14499829, 'id_str': '14499829', 'indices': [1, 5]}], 'urls': [{'url': 'https://t.co/JqUe1dAgHG', 'expanded_url': 'https://twitter.com/i/web/status/1522430408025026560', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1289235667516456962, 'id_str': '1289235667516456962', 'name': 'Facts', 'screen_name': 'BefittingFacts', 'location': 'India', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 169288, 'friends_count': 532, 'listed_count': 243, 'created_at': 'Fri Jul 31 16:25:21 +0000 2020', 'favourites_count': 21572, 'utc_off ...
